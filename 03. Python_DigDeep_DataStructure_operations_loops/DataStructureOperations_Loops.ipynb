# %%
import MyLibrary

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
MyLibrary.a
# Out:
# 10

# %%
#Type CAsting / Type conversion
X = 10
print(type(X))
# Out:
# <class 'int'>

# %%
X = 10 + 0.5
print(type(X))
# Out:
# <class 'float'>

# %%
X = 10 + "Far"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 X = 10 + "Far"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
A = 10
print(type(A))

B = float(A)
print(type(B))
# Out:
# <class 'int'>
# <class 'float'>

# %%
A = 10.05
print(type(A))

B = int(A)
print(B)
print(type(B))
# Out:
# <class 'float'>
# 10
# <class 'int'>

# %%
A = 10.80
print(type(A))

B = int(A) #int wont approximate - it discards
print(B)
print(type(B))
# Out:
# <class 'float'>
# 10
# <class 'int'>

# %%
A = "Laxmi"
int(A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 A = "Laxmi"
# ----> 2 int(A)
#
# ValueError: invalid literal for int() with base 10: 'Laxmi'

# %%
A = '0032'
int(A)
# Out:
# 32

# %%
ctrl+enter #Execute and selection in same cell
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 ctrl+enter
#
# NameError: name 'ctrl' is not defined

# %%
shift+enter #execute and go to the next lin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 shift+enter
#
# NameError: name 'shift' is not defined

# %%
print(5+5)
# Out:
# 10

# %%
lst = [1,2,3,4,5]

# %%
lst[0]
# Out:
# 1

# %%
len(lst)
# Out:
# 5

# %%
lst[1] = 'banana'

# %%
print(lst)
# Out:
# [1, 'banana', 3, 4, 5]

# %%
del lst #deleting a list

# %%
a = 10
del a

# %%
print(lst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1896/2697629934.py in <cell line: 0>()
# ----> 1 print(lst)
#
# NameError: name 'lst' is not defined

# %%
lst = [1,2,3,4,5]

# %%
del lst[0]

# %%
lst
# Out:
# [2, 3, 4, 5]

# %%
del lst[3]

# %%
lst
# Out:
# [2, 3, 4]

# %%
lst = [100,200,300,400]

# %%
lst.append(500)

# %%
lst.append?

# %%
help(lst.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
lst
# Out:
# [100, 200, 300, 400, 500]

# %%
lst.insert(2, 250)

# %%
lst
# Out:
# [100, 200, 250, 300, 400, 500]

# %%
lst = [100,200,300,400]

# %%
lst1 = [600,700,800,900]
lst.append(lst1) #Single element appending method

# %%
lst[4]
# Out:
# [600, 700, 800, 900]

# %%
lst #list of list - list inside a list
# Out:
# [100, 200, 300, 400, [600, 700, 800, 900]]

# %%
lst.extend(lst1) #Untied and put each element of second list as first list elements

# %%
lst
# Out:
# [100, 200, 300, 400, [600, 700, 800, 900], 600, 700, 800, 900]

# %%
tuple1 = (600,700,800,900)
lst.append(tuple1) #Single element appending method

# %%
lst #A tuple inside a list..
# Out:
# [100,
#  200,
#  300,
#  400,
#  [600, 700, 800, 900],
#  600,
#  700,
#  800,
#  900,
#  (600, 700, 800, 900)]

# %%
type(lst)
# Out:
# list

# %%
lst.extend(tuple1)

# %%
lst
# Out:
# [100,
#  200,
#  300,
#  400,
#  [600, 700, 800, 900],
#  600,
#  700,
#  800,
#  900,
#  (600, 700, 800, 900),
#  600,
#  700,
#  800,
#  900]

# %%
lst2 = ["oranges",'apples','mangoes']

# %%
firstData = lst2.pop() #Removed and returned

# %%
lst2
# Out:
# ['oranges', 'apples']

# %%
firstData
# Out:
# 'mangoes'

# %%
lst2 = ["oranges",'apples','mangoes']
firstElement = lst2.pop(0)

# %%
firstElement
# Out:
# 'oranges'

# %%
firstElement = lst2.pop(0)

# %%
firstElement
# Out:
# 'apples'

# %%
firstElement = lst2.pop(0)

# %%
firstElement
# Out:
# 'mangoes'

# %%
firstElement = lst2.pop(0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1896/3645720855.py in <cell line: 0>()
# ----> 1 firstElement = lst2.pop(0)
#
# IndexError: pop from empty list

# %%
lst2 = ["oranges",'apples','mangoes']
secondElement = lst2.pop(1)

# %%
secondElement
# Out:
# 'apples'

# %%
secondElement = lst2.pop(1)

# %%
secondElement
# Out:
# 'mangoes'

# %%
secondElement = lst2.pop(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1896/4130390281.py in <cell line: 0>()
# ----> 1 secondElement = lst2.pop(1)
#
# IndexError: pop index out of range

# %%
lst2 = ["oranges",'apples','mangoes',"oranges"]
lst2.remove('oranges') #Value not index

# %%
lst2
# Out:
# ['apples', 'mangoes', 'oranges']

# %%
lst1 = [2,1,3,6,5,4]
lst1.sort()

# %%
lst1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lst1.sort(reverse = True) #Descentring sort reverse

# %%
lst1
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
lst1 = [2,1,3,6,5,4] #whatever order just reverse as such
lst1.reverse()

# %%
lst1
# Out:
# [4, 5, 6, 3, 1, 2]

# %%
lst1 = ['A','aa','aaaa'] #you need to have homogenious lists to be able to sort it if mixes cannot compare between elements

# %%
lst1.sort()

# %%
lst1
# Out:
# ['A', 'aa', 'aaaa']

# %%
#Lists can be Sliced: [start:stop:step]
lst1 = [2,1,3,6,5,4]

# %%
#Accessing list element via slices..
lst1[0:5:2] #From start -> end-1
# Out:
# [2, 3, 5]

# %%
lst1[0:2:1] #[Start:stop-1:step]
# Out:
# ['A', 'aa']

# %%
lst1 = [2,1,3,6,5,4]

# %%
lst1[0:4:1] #end-1th
# Out:
# [2, 1, 3, 6]

# %%
lst1[0:4:2] #end-1th List Slicing - Where you access multiple elements in start:stop-1
# Out:
# [2, 3]

# %%
lst1[0:5]
# Out:
# [2, 1, 3, 6, 5]

# %%
lst1 = [2,1,3,6,5,4]

# %%
del lst1[0:5]

# %%
lst1
# Out:
# [4]

# %%
lst1 = [1,3,6,5,4,"apple",'2']

# %%
(2 in lst1) and ('2' in lst1) #Checking for membership of an element in the list return type is boolean
#Checks memberships and datatypes
# Out:
# False

# %%
100 in lst1
# Out:
# False

# %%
['Orange']*20
# Out:
# ['Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange',
#  'Orange']

# %%
[[1,2,3,4]]*200

# %%
lst1 = [0,1,2,3,4,"apple",'2']

# %%
lst1[0:3]
# Out:
# [0, 1, 2]

# %%
lst1[:3] #in list slicing default start is 0, just like default step being 1
# Out:
# [1, 3, 6]

# %%
lst1[2:] #end is whole list
# Out:
# [6, 5, 4, 'apple', '2']

# %%
lst1 = [1,3,6,5,4,"apple",'2']

# %%
lst1[-1]
# Out:
# '2'

# %%
lst1[-1::-1] #Starting from reverse position

# %%
lst1[::-1] #Step 1 if I give the step as -1 and dont give anything as start the first index is -1
# Out:
# ['2', 'apple', 4, 3, 2, 1, 0]

# %%
lst = [0,1,2,3,4]

# %%
lst[-3:]# pointer in -3 as start default step is 1 [-3,-2,-1 <eol>]
# Out:
# [2, 3, 4]

# %%
lst = [0,1,2,3,4]
lst[-3::-1]
# Out:
# [2, 1, 0]

# %%
lst = ['A', 'B']
lst.extend('B')
lst.extend('A')
print(lst)
# Out:
# ['A', 'B', 'B', 'A']

# %%
lst = ['A','B']
lst.append(lst[::-1])

# %%
lst
# Out:
# ['A', 'B', ['B', 'A']]

# %%
lst = ['A','B']
lst.extend(lst[::-1])

# %%
lst = ['A','B']
lst.extend('C')

# %%
lst = ['A','B']
lst.append("C")

# %%
lst
# Out:
# ['A', 'B', 'C']

# %%
lst = ['A','B']
lst+lst[::-1]
# Out:
# ['A', 'B', 'B', 'A']

# %%
lst1 = ['A','B'] #whatever order just reverse as such
lst2 = lst1 + lst1[::-1]
lst2

# %%
lst=["A","B"]
lst.extend(lst[-1::-1])

# %%
lst
# Out:
# ['A', 'B', 'B', 'A']

# %%
tup = (0,1,2,3,4,5)
tup[0:5]
# Out:
# (0, 1, 2, 3, 4)

# %%
del tup[0:3] #TypeError: 'tuple' object does not support item deletion
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1896/2649262652.py in <cell line: 0>()
# ----> 1 del tup[0:3]
#
# TypeError: 'tuple' object does not support item deletion

# %%
tup = (0,1,2,3,4,0,5)

# %%
tup.count(0)
# Out:
# 2

# %%
tup.index(0) #tuple.index(value whose index I have retrieve)
# Out:
# 0

# %%
tup.index(100,2) #Starting from 1st index skipped 0th index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1896/2267881649.py in <cell line: 0>()
# ----> 1 tup.index(100,2) #Starting from 1st index skipped 0th index
#
# ValueError: tuple.index(x): x not in tuple

# %%
A = {1,1,2,3,4}

# %%
A #Data structure that should hold no-duplicates you can use set..
# Out:
# {1, 2, 3, 4}
