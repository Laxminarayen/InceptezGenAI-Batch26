# %%
import pandas as pd #Alias to the tool that we will be consuming

# %%
# !pip install pandas

# %%
data = pd.read_csv("purchases.csv")

# %%
data.head()
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data = {"Materials": ['Silk','Rose'],
        "Percent": [100,20]}

# %% [markdown]
# 1.  Series
# 2.  Data Frame

# %%
pandas_data = pd.DataFrame(data)
pandas_data
# Out:
#   Materials  Percent
# 0      Silk      100
# 1      Rose       20

# %%
type(pandas_data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pandas_data['Materials'])
# Out:
# pandas.core.series.Series

# %%
purchases = pd.read_json("purchases.json")

# %%
purchases #Columns
#Index
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
data = {"Materials": ['Silk','Rose'],
        "Percent": [100,20]}

pandas_data = pd.DataFrame(data)
pandas_data
# Out:
#   Materials  Percent
# 0      Silk      100
# 1      Rose       20

# %%
pandas_data = pd.DataFrame(data, index = ["Yes","No"])
pandas_data
# Out:
#     Materials  Percent
# Yes      Silk      100
# No       Rose       20

# %%
data = {"Materials": ['Silk','Rose'],
        "Percent": [100,20],
        "Std": [1,2]}

# %%
pandas_data = pd.DataFrame(data, index = ["True","False"])
#index is just an alias to the row as names
pandas_data
# Out:
#       Materials  Percent  Std
# True       Silk      100    1
# False      Rose       20    2

# %%
pandas_data = pd.DataFrame(data)
pandas_data
# Out:
#   Materials  Percent  Std
# 0      Silk      100    1
# 1      Rose       20    2

# %%
pd.DataFrame?

# %%
#Column - Columns in pandas
#Index - Name given to rows

# %%
no_colname = pd.read_csv("purchases_withoutcolums.csv")

# %%
no_colname
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2
# 0       June           3           0
# 1     Robert           2           3
# 2       Lily           0           7
# 3      David           1           2

# %%
no_colname.columns = ['1','2','3']

# %%
no_colname
# Out:
#         1  2  3
# 0    June  3  0
# 1  Robert  2  3
# 2    Lily  0  7
# 3   David  1  2

# %%
#Pyspark - BigData - HeavyDuty Pickup Truck
#Pandas Dataframe - Thar - High performace Cars

# %%
# !pip install pysqlite3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 43.9 MB/s eta 0:00:00
# ...

# %%
import sqlite3

# %%
con = sqlite3.connect("database.db")

# %%
df = pd.read_sql_query("SELECT * FROM purchases",con)

# %%
df
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %%
df.set_index("index")
# Out:
#         apples  oranges
# index
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df.head(2)
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3

# %%
df.head(3)
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7

# %%
df.head()
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %%
df.tail()
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %%
df.tail(1)
# Out:
#    index  apples  oranges
# 3  David       1        2

# %%
MoviesData = pd.read_csv("IMDB-Movie-Data.csv")

# %%
MoviesData.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
MoviesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
MoviesData.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
import pandas as pd

# %%
MoviesData = pd.read_csv("IMDB-Movie-Data.csv")

# %%
MoviesData.shape
# Out:
# (1000, 12)

# %%
MoviesData.tail(2)
# Out:
#      Rank         Title                  Genre  \
# 998   999  Search Party       Adventure,Comedy
# 999  1000    Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 998                 93     5.6   4881                 NaN       22.0
# 999                 87     5.3  12435               19.64       11.0

# %%
MoviesData.append?
# Out:
# Object `MoviesData.append` not found.

# %%
#MoviesData_duplicates = MoviesData.append(MoviesData) #This is removed / deprecited
#MoviesData_duplicates

#https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.append.html

# %%
Movie_data_duplicates = pd.concat([MoviesData,MoviesData])

# %%
Movie_data_duplicates.shape
# Out:
# (2000, 12)

# %%
#The first impurity in the dataset is the presence of duplcates - Do distributions also represent frequency
temp_df = Movie_data_duplicates.drop_duplicates()

# %%
temp_df.shape
# Out:
# (1000, 12)

# %%
Movie_data_duplicates.drop_duplicates(inplace = True) #inplace operations are now arguments

# %%
Movie_data_duplicates.shape
# Out:
# (1000, 12)

# %%
Movie_data_duplicates = pd.concat([MoviesData,MoviesData])

# %%
lst = [-1,2,3,4]
lst
# Out:
# [-1, 2, 3, 4]

# %%
#lst = lst.append(10) #Reassignig
lst.append(10) #inplace operations

# %%
lst
# Out:
# [-1, 2, 3, 4, 10]

# %%
Movie_data_duplicates.shape
# Out:
# (1200, 12)

# %%
Movie_data_duplicates.drop_duplicates(inplace = True,keep = False) #Keep will drop all the duplicates.. If two rows are the same then both the rows will be dropped

# %%
Movie_data_duplicates.shape
# Out:
# (800, 12)

# %%
MoviesData.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#Dictionary style
MoviesData.rename(columns = {"Runtime (Minutes)": "Runtime", "Revenue (Millions)": "Revenue"}, inplace = True)

# %%
MoviesData.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
#list style change
MoviesData.columns = ['rank', 'title', 'genre', 'Description', 'Director', 'Actors', 'Year',
       'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore']

# %%
MoviesData.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
MoviesData[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_32142/4074082404.py in <cell line: 0>()
# ----> 1 MoviesData[1]
#
# ...

# %%
Pandas Data Frame -> Pandas 1D Series -> Data

# %%
MoviesData['rank']
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: rank, Length: 1000, dtype: int64

# %%
MoviesData['genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: genre, Length: 1000, dtype: object

# %%
#Access prometheus - Via indexing

# %%
MoviesData['title'][1]
# Out:
# 'Prometheus'

# %%
#[rowIndex,columnIndex]

# %%
MoviesData.iloc[1,1] # index Location
# Out:
# 'Prometheus'

# %%
MoviesData.iloc[:10,1]
# Out:
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# 5             The Great Wall
# 6                 La La Land
# 7                   Mindhorn
# 8         The Lost City of Z
# 9                 Passengers
# Name: title, dtype: object

# %%
MoviesData.iloc[:10,:5]
# Out:
#    rank                    title                       genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
#MoviesData.merge()

# %%
MoviesData.iloc[5,:]
# Out:
# rank                                                           6
# title                                             The Great Wall
# genre                                   Action,Adventure,Fantasy
# Description    European mercenaries searching for black powde...
# Director                                             Yimou Zhang
# Actors             Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# Year                                                        2016
# Runtime                                                      103
# Rating                                                       6.1
# Votes                                                      56036
# Revenue                                                    45.13
# Metascore                                                   42.0
# Name: 5, dtype: object

# %%
type(MoviesData.iloc[5])
# Out:
# pandas.core.series.Series

# %%
MoviesData.iloc[5] #Rows is a pandas series - Row object
# Out:
# rank                                                           6
# title                                             The Great Wall
# genre                                   Action,Adventure,Fantasy
# Description    European mercenaries searching for black powde...
# Director                                             Yimou Zhang
# Actors             Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# Year                                                        2016
# Runtime                                                      103
# Rating                                                       6.1
# Votes                                                      56036
# Revenue                                                    45.13
# Metascore                                                   42.0
# Name: 5, dtype: object

# %%
MoviesData.iloc[5:6] #Rows is a pandas series - Row object
# Out:
#    rank           title                     genre  \
# 5     6  The Great Wall  Action,Adventure,Fantasy
#
#                                          Description     Director  \
# 5  European mercenaries searching for black powde...  Yimou Zhang
#
#                                           Actors  Year  Runtime  Rating  \
# 5  Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016      103     6.1
#
#    Votes  Revenue  Metascore
# 5  56036    45.13       42.0

# %%
MoviesData.iloc[:5]
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
MoviesData.iloc[5,'title']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     965             try:
# --> 966                 self._validate_key(k, i)
#     967             except ValueError as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1613         else:
# -> 1614             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1615
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32142/2176658994.py in <cell line: 0>()
# ...

# %%
MoviesData.iloc[[10,20,30],[0,1,6]]
# Out:
#     rank                                    title  Year
# 10    11  Fantastic Beasts and Where to Find Them  2016
# 20    21                                     Gold  2016
# 30    31                                 Why Him?  2016

# %%
MoviesData.iloc[[10,20,30],['title',1,6]] #indexing based
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_32142/1884736764.py in <cell line: 0>()
# ----> 1 MoviesData.iloc[[10,20,30],['title',1,6]]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
#Index - Rows in pandas
#columns - columns

# %%
import pandas as pd
MoviesData =  pd.read_csv("https://raw.githubusercontent.com/Laxminarayen/InceptezGenAI-Batch26/refs/heads/main/08.%20Python_Day7_Pandas/IMDB-Movie-Data.csv")

# %%
MoviesData.iloc[[10,20,30],[0,1,6]]
# Out:
#     rank                                    title  Year
# 10    11  Fantastic Beasts and Where to Find Them  2016
# 20    21                                     Gold  2016
# 30    31                                 Why Him?  2016

# %%
MoviesData.head()

# %%
MoviesData.iloc[[5]] #Rows is a pandas series - Row object
# Out:
#    rank           title                     genre  \
# 5     6  The Great Wall  Action,Adventure,Fantasy
#
#                                          Description     Director  \
# 5  European mercenaries searching for black powde...  Yimou Zhang
#
#                                           Actors  Year  Runtime  Rating  \
# 5  Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016      103     6.1
#
#    Votes  Revenue  Metascore
# 5  56036    45.13       42.0

# %%
#SQL - Knife - ETL
#Pandas - Swiss - before building predictions we will 2nd round of cleaning

# %%
#iloc - uses co-ordinates (int) (15' east 13' south)
#loc - Names (MTR restaurant in bangalore)

# %%
MoviesData.iloc[10,'title']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     965             try:
# --> 966                 self._validate_key(k, i)
#     967             except ValueError as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1613         else:
# -> 1614             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1615
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32142/4008797900.py in <cell line: 0>()
# ...

# %%
MoviesData.loc[10,'title']
# Out:
# 'Fantastic Beasts and Where to Find Them'

# %%
MoviesData.loc[MoviesData['rank']==10,'title'] #Alphas or boolean
# Out:
# 9    Passengers
# Name: title, dtype: object

# %%
MoviesData.loc[MoviesData['rank']<10,'title'] #It is basically WHERE clause and SELECT Statement..
# Out:
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# 5             The Great Wall
# 6                 La La Land
# 7                   Mindhorn
# 8         The Lost City of Z
# Name: title, dtype: object

# %% [markdown]
# ## Null values are problematic!!!!!!
#
#
# 1.   Removing the rows where missing values are present
# 2.   Replace it with statistically meaningful values

# %%
MoviesData.isna().sum() #NA - Not Available
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7120/2160116862.py in <cell line: 0>()
# ----> 1 MoviesData.isna().sum() #NA - Not Available
#
# NameError: name 'MoviesData' is not defined

# %%
pd.DataFrame?

#MAke sure we find what are the values converted
#to NA inside pandas

# %%
MoviesData.dropna(inplace = True)

# %%
MoviesData.shape
# Out:
# (838, 12)

# %%
def rating_function(x):
  if x >=8.0:
    return "good"
  else:
    return "bad"

# %%
MoviesData.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
MoviesData['Rating_good_bad'] = MoviesData['Rating'].apply(rating_function) #reassignment operation

# %%
MoviesData.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime  Rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...
