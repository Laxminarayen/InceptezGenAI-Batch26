# %% [markdown]
# # Inceptez GenAI Batch 26: Assignment 3
# ## Topic: Control Flow & Functions (Day 5)
#
# **Student Name:** [Your Name]
# **Date:** April 2026
#
# ---
#
# ### Instructions:
# 1. Complete the code for each task below.
# 2. Ensure you include **Docstrings** for all user-defined functions.
# 3. Test your code with different inputs.

# %% [markdown]
# ### Q1: The Security Gate (While Loop)
# Create a login system that:
# - Asks the user for a password input.
# - Gives the user exactly **3 attempts**.
# - If the password is `Inceptez2026`, print "Access Granted" and exit the loop.
# - If the password is wrong, print "Incorrect password. X attempts remaining."
# - After 3 failed attempts, print "Account Locked: Please contact admin."

# %%
# Write your logic here
password_correct = "Inceptez2026"
attempts = 3 #Loop initialization
#Counter
while attempts > 0: #Loop condition
  password = input("Enter password: ")
  if password == password_correct:
    print("Access Granted")
    break
  else:
    attempts-=1 #Increment / Decrement statement bitwise operator
    print(f"Incorrect password. {attempts} attempts remaining.")
    if attempts == 0:
      print("Account Locked: Please contact admin.")
# Out:
# Enter password: Laxmi
# Incorrect password. 2 attempts remaining.
# Enter password: Ghj
# Incorrect password. 1 attempts remaining.
# Enter password: irts
# Incorrect password. 0 attempts remaining.
# Account Locked: Please contact admin.

# %% [markdown]
# ### Q2: Filtered Iteration (Break & Continue)
# Write a program that iterates through a range of numbers from 1 to 30:
# - If the number is divisible by 5, **skip** it using `continue`.
# - If the number is 27, **stop** the loop entirely using `break`.
# - Print all other numbers on the same line.

# %%
# Write your code here
for i in range(1, 31):
    if i == 27:
        break
    if i % 5 == 0:
        continue
    print(i, end=" ") #print by default uses end='\n' = newline as my ending statement
# Out:
# 1 2 3 4 6 7 8 9 11 12 13 14 16 17 18 19 21 22 23 24 26

# %%
value = range(1,30)
finalValue = ""
for number in value :
  if(number % 5 == 0):
    continue
  elif (number == 27) :
    break
  else :
    finalValue = finalValue+ str(number)+" "
print(finalValue)
# Out:
# 1 2 3 4 6 7 8 9 11 12 13 14 16 17 18 19 21 22 23 24 26

# %%
numbers = []
for num in range(1, 31):
  if num % 5 == 0:
    continue
  if num == 27:
    break
  numbers.append(str(num))
print("Numbers: " + ", ".join(numbers))
# Out:
# Numbers: 1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26

# %%
lst_str = ['a','b','c']
print(".".join(lst_str))

newStr = ".".join(lst_str) #DataStructure
# Out:
# a.b.c

# %%
newStr
# Out:
# 'a.b.c'

# %% [markdown]
# ### Q3: Dynamic Geometry (Functions & Default Args)
# Create a function called `calculate_area` that:
# 1. Takes two parameters: `length` and `width`.
# 2. Includes a **Docstring** explaining its purpose and parameters.
# 3. If `width` is not provided, the function should treat the shape as a **square** (width = length).
# 4. Returns the area.

# %%
def calculate_area(length, width=None): #Default value assigned to Width = None
    """
    Calculate area of rectangle or square.
    """
    # Write your logic here
    if width is None:
        return length * length
    else:
        return length * width
# Test cases
print(f"Area: {calculate_area(10, 5)}") #format pritting
# Out:
# Area: 50

# %%
def calculate_area(width=None,length): #Default value assigned to Width = None
    """
    Calculate area of rectangle or square.
    """
    # Write your logic here
    if width is None:
        return length * length
    else:
        return length * width
# Out:
#   File "/tmp/ipykernel_14055/2425189232.py", line 1
#     def calculate_area(width=None,length): #Default value assigned to Width = None
#                                   ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
print("Area: {calculate_area()}")

# %%
calculate_area(10)
# Out:
# 100

# %%
def calculate_area(length, width=None):
# Out:
#   File "/tmp/ipykernel_14055/327197606.py", line 1
#     def calculate_area(length, width=None):
#                                            ^
# SyntaxError: incomplete input

# %%
def calculate_area(length, width=None):
  pass #Pass in python is a temporary placeholder for incomplete modules
