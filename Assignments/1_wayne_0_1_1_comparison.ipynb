# %% [markdown]
# # Assignment: Python Functions and Classes
# Based on the concepts covered in `Python_Day5.ipynb`.
# ---

# %% [markdown]
# ### Question 1: Fixing Syntax Errors
# The following function definition is incorrect based on the rules of parameter ordering[cite: 1]. Fix the code so it runs without a `SyntaxError`.

# %%
# FIX THIS CODE:
def calculate_area(unit="cm", length, width):
    print(f"Area: {length * width} {unit}")

# Correct it below:

# %% [markdown]
# ### Question 2: Variable Positional Arguments (*args)
# Create a function called `sum_all` that uses `*args` to take any number of integers and returns their sum[cite: 1]. Print the result of `sum_all(10, 20, 30, 40)`.

# %%
def sum_all(*nums):
    # Your code here
    pass

# %% [markdown]
# ### Question 3: Working with Class Constructors
# Create a class named `Smartphone`.
# 1. The `__init__` method should take `brand`, `model`, and `storage` (default 128)[cite: 1].
# 2. Add a method `describe()` that prints the phone's details using `self`[cite: 1].

# %%
class Smartphone:
    # Your code here
    pass

phone1 = Smartphone("Apple", "iPhone 15", 256)
phone1.describe()

# %% [markdown]
# ### Question 4: Understanding the Global Keyword
# Modify the code below so that calling the `update_score()` function changes the global variable `score` to 100[cite: 1].

# %%
score = 0

def update_score():
    # Use the appropriate keyword here
    score = 100

update_score()
print(score) # Should print 100

# %% [markdown]
# ### Question 5: Keyword Arguments (**kwargs)
# Write a class method `print_filters` (inside a class of your choice) that accepts `**kwargs`. The method should loop through the items and print each key-value pair[cite: 1].

# %%
class DataTool:
    def print_filters(self, **filters):
        # Your code here
        pass

tool = DataTool()
tool.print_filters(category="Electronics", price_limit=500)
